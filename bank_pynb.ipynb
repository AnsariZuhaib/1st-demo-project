# %% [markdown]
# <a href="https://colab.research.google.com/github/AnsariZuhaib/1st-demo-project/blob/main/bank_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import bcrypt

class BankDatabaseManager:
    def __init__(self, db="bank_database.db"):
        self.conn = sqlite3.connect(db)
        self.cursor = self.conn.cursor()
        self.create_users_table()
        self.create_transaction_table()

    # USERS TABLE
    def create_users_table(self):
        self.cursor.execute("""
        CREATE TABLE IF NOT EXISTS users(
            serial_no INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT,
            password_id TEXT UNIQUE,
            balance INTEGER DEFAULT 0,
            password TEXT,
            pin int,
            pin_attempt int default 0
            identi_no INTEGER
        );
        """)
        self.conn.commit()

    # TRANSACTION TABLE
    def create_transaction_table(self):
        self.cursor.execute("""
        CREATE TABLE IF NOT EXISTS transactions(
            name TEXT,
            password_id TEXT,
            amount INTEGER,
            trans_pin int,
            transaction_type TEXT,
            time TIMESTAMP default current_timestamp,
            FOREIGN KEY(password_id) REFERENCES users(password_id)
        );
        """)
        self.conn.commit()

    def login(self):
        id_ = input("enter identi_no: ")
        password = input("enter password: ")
        self.cursor.execute("SELECT password FROM users WHERE identi_no = ?", (id_,))
        data = self.cursor.fetchone()
        if data:
          stored_password = data[0]
        if bcrypt.checkpw(password.encode('utf-8'), stored_password):
             print("correct password")
             return True
        else:
            print("incorrect password")
            return False

        if self.login():
              main.menu()
        else:
              print("login failed")

    def check_balance(self):
        name = input("Enter name: ")
        self.cursor.execute("SELECT balance FROM users WHERE name=?", (name,))
        data = self.cursor.fetchone()

        if data:
            print("Balance:", data[0])
        else:
            print("User not found")

    def credit(self):
        id_no = input("Enter id no: ")
        self.cursor.execute(
          "SELECT name , identi_no, is_active FROM users WHERE identi_no = ?",(id_no,)
        )
        data = self.cursor.fetchone()

        if data is None:
          print("user not found")
          return

        name,identi_no,is_active = data

        if is_active == 0:
            print("account is frozen")
            return
        try:
          amount = int(input("enter amount to be credited: "))
          if amount <= 0:
            print("invalid amount")
            return
        except:
            print("enter valid amount: ")
            return

        try:
          self.cursor.execute(
            "UPDATE users SET balance = balance + ? WHERE identi_no=?",
            (amount, id_no)
        )

          self.cursor.execute("SELECT password_id FROM users WHERE name=?", (name,))
          password_id = self.cursor.fetchone()[0]

          self.cursor.execute(
            "INSERT INTO transactions VALUES(?,?,?,?,?)",
            (name, password_id, amount, "credit",time)
        )

          self.conn.commit()
          print("Amount credited")

        except Exception as e:
          self.conn.rollback()
          print("Error:", e)



    def debit(self):
        id_no = input("Enter identification number: ")

        self.cursor.execute(
           "SELECT name, identi_no, balance , is_active, password_id FROM users WHERE identi_no = ?",(id_no,)
       )
        data = self.cursor.fetchone()
        if data is None:
          print("user not found: ")
          return

        if data[3] == 0:
          print("account is frozen")
          return

        try:
         amount = int(input("enter amount to be debited: "))

         name, identi_no, balance, is_active, password_id = data

         if amount > data[2]:
            print("Insufficient balance")
            return
        except:
            print("enter valid amount:")
            return

        try:
         self.cursor.execute(
            "UPDATE users SET balance = balance - ? WHERE identi_no=?",
            (amount, id_no)
        )

         self.cursor.execute("SELECT password_id FROM users WHERE name=?", (name,))
         password_id = self.cursor.fetchone()[0]

         self.cursor.execute(
            "INSERT INTO transactions VALUES(?,?,?,?,?)",
            (name, password_id, amount, "debit",time)
        )

         self.conn.commit()
         print("Amount debited")

        except Exception as e:
         self.conn.rollback()
         print("Error:", e)

    def transfer(self):
        sender = input("Sender_id: ")
        receiver = input("Receiver_id: ")
        amount = int(input("Amount: "))

        self.cursor.execute("SELECT balance FROM users WHERE name=?", (sender,))
        data = self.cursor.fetchone()

        if not data or data[0] < amount:
            print("Insufficient balance")
            return

        pin_ = input("enter your pin: ")
        self.cursor.execute(
            "select pin,pin_attempt,is_active from users where password_id=?",(self.current_user))
        pin,pin_attempt,is_active = data
         if not data[2] == 1:
          print("accpunt is frozen")

        if isinstance(pin, int)
        pin = pin.encode('utf-8')

        if bycrypt.chechpw(pin_.encode('utf-8'), pin)
        print("correct pin")

        self.cursor.execute(
           " update users set pin_attempt = 0 where password_id = ?",(self.current_user,)
        )
        else:
          attempt_count += 1
        if attempt_count >= 3:
            print("too many attempts , account is frozen")
        self.cursor.execute(
            "update users is_active = 0 where password_id = ?",(self.current_user,)

        )




        # Update balances
        self.cursor.execute(
            "UPDATE users SET balance = balance - ? WHERE name=?",
            (amount, sender)
        )
        self.cursor.execute(
            "UPDATE users SET balance = balance + ? WHERE name=?",
            (amount, receiver)
        )


        self.cursor.execute("SELECT password_id FROM users WHERE name=?", (sender,))
        sender_id = self.cursor.fetchone()[0]

        self.cursor.execute("SELECT password_id FROM users WHERE name=?", (receiver,))
        receiver_id = self.cursor.fetchone()[0]


        self.cursor.execute(
            "INSERT INTO transactions VALUES(?,?,?,?)",
            (sender, sender_id, amount, "transfer")
        )
        self.cursor.execute(
            "INSERT INTO transactions(name,(receiver, receiver_id, amount, "received"),
             values (?,?,?,?)
        )

        self.conn.commit()
        print("Transfer successful")



    def transaction_history(self):
        password_id = input("Enter password id: ")

        self.cursor.execute("""
        SELECT users.name, transactions.amount, transactions.transaction_type, transactions.time
        FROM users
        INNER JOIN transactions
        ON users.password_id = transactions.password_id
        WHERE users.password_id = ?
        """, (password_id,))

        for row in self.cursor.fetchall():
            print(row)


    def menu(self):
        while True:
            print("\n1 Check Balance")
            print("2 Credit")
            print("3 Debit")
            print("4 Transfer")
            print("5 Transaction History")
            print("6 Exit")

            choice = input("Choice: ")

            if choice == "1":
                self.check_balance()
            elif choice == "2":
                self.credit()
            elif choice == "3":
                self.debit()
            elif choice == "4":
                self.transfer()
            elif choice == "5":
                self.transaction_history()
            elif choice == "6":
                break

        self.conn.close()

    def role_column(self):
      self.cursor.execute(
        "ALTER TABLE users ADD COLUMN role TEXT DEFAULT 'user'"
        )
      self.cursor.execute(
          "ALTER TABLE users ADD COLUMN is_active BOOLEAN DEFAULT TRUE"
      )
      self.conn.commit()

    def role_assign(self,id):
       self.cursor.execute(
            "UPDATE users SET role = 'admin' WHERE serial_no = ?", (id,)
        )
       self.conn.commit()

    def role_find(self):
        user_id = input("enter user id:")
        self.cursor.execute(
            "SELECT role FROM users WHERE id = ?,(user_id,)"
            )
        data = self.cursor.fetchone()
        if data and data[0] == 'admin':
           self.admin_menu()
        else:
           self.menu()

    def admin_menu(self):
      while True:
        print("/n select 1 to view data: ")
        print("select 2 to freeze account: ")
        print("select 3 to delete user: ")
        print("select 4 to unfreeze account: ")
        print("select 5 to view total balance in bank: ")
        print("select 6 to exit")
        admin_choice = int(input("enter your choice: "))

        if admin_choice == 1:
         self.cursor.execute(
            "SELECT name, id , is_active, balance FROM users"
        )
         data = self.cursor.fetchall()
         self.conn.commit()

        elif admin_choice == 2:
         user_id = input("enter user id : ")
         self.cursor.execute(
            "UPDATE users SET is_active = 0 WHERE id = ?,(user_id,)"
        )
         self.conn.commit()

        elif admin_choice == 3:
         user_id = (input("enter user id: "))
         self.cursor.execute(
            "DELETE FROM users WHERE id = ?,(user_id,)"
        )
         self.conn.commit()

        elif admin_choice == 4:
          user_id = input("enter user id: ")
          self.cursor.execute(
             "UPDATE users SET is_active = 1 WHERE id = ?,(user_id,)"
         )
          self.conn.commit()

        elif admin_choice == 5:
          self.cursor.execute(
             "SELECT SUM(balance) FROM users"
         )
          data = self.cursor.fetchone()
          self.conn.commit()

        elif admin_choice == 6:
          break


bank = BankDatabaseManager()
if bank.login():
    bank.menu()
else:
    print("Login failed")
    self.cursor.close()
# Out:
# enter identification_number: 8900009
# enter password: Zuhaib#@
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-1403/736005990.py in <cell line: 0>()
#     318
#     319 bank = BankDatabaseManager()
# --> 320 if bank.login():
#     321     bank.menu()
#     322 else:
#
# /tmp/ipython-input-1403/736005990.py in login(self)
#      43         if data:
#      44           stored_password = data[0]
# ---> 45         if bcrypt.checkpw(password.encode('utf-8'), stored_password):
#      46              print("correct password")
#      47              return True
#
# UnboundLocalError: cannot access local variable 'stored_password' where it is not associated with a value

# %%
pip install bcrypt
# Out:
# Collecting bcrypt
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: bcrypt
# Successfully installed bcrypt-5.0.0
